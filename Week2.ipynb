# %% [markdown]
# <a href="https://colab.research.google.com/github/irsyaddani/PCVK_2024_17/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Irsyad Danisaputra
# <br>NIM: 2241720233
# <br>Absen: 17
# <br>Kelas: TI-3E

# %% [markdown]
# # PRAKTIKUM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Kuliah/Semester5/PCVK/Modul2/Foto_Irsyad.jpg')
plt.imshow(img)

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img3)

# %% [markdown]
# 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan
# citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/Kuliah/Semester5/PCVK/Modul2/Foto_Irsyad.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#Simpan file image
cv.imwrite('/content/drive/MyDrive/Kuliah/Semester5/PCVK/Modul2/Foto_Irsyad.jpg', img5)

#Tampilkan plot dengan ukuran kanvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program.

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# 5. Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih File kemudian “Save a copy in GitHub”.

# %% [markdown]
# # PERTANYAAN

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?

# %% [markdown]
# **Jawab**:
# <br> Tanpa Matplotlib
#
# - Gambar yang ditampilkan akan menggunakan format warna BGR karena menggunakan OpenCV.
# - Gambar tidak akan ditampilkan dalam plot
#
# <br> Dengan Matplotlib
# - Gambar yang ditampilkan akan menggunakan format warna RGB.
# - Gambar akan ditampilkan dalam plot

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?

# %% [markdown]
# **Jawab:**
# <br> Penggunaan int16 atau int32 tidak memberikan manfaat visual tambahan untuk gambar 8-bit, tetapi bisa berguna untuk operasi pemrosesan citra khusus yang memerlukan rentang nilai lebih luas atau nilai negatif.
#
# Perbedaan dari int16 dan int32 hanyalah terletak pada penyimpanan memori yang lebih banyak untuk int32.

# %% [markdown]
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut:
#
# ```
# from google.colab.patches import cv2_imshow
# from skimage import io
#
# ```

# %% [markdown]
# **Jawab:**
# <br> Perintah tersebut digunakan untuk menampilkan gambar menggunakan OpenCV pada Google Colab.

# %% [markdown]
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# **Jawab:**
# <br>Kode "from skimage import io" digunakan untuk memuat, menampilkan, dan menyimpan gambar dalam pustaka scikit-image (skimage), yang merupakan pustaka Python untuk pemrosesan gambar

# %% [markdown]
# # TUGAS PRAKTIKUM

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
#
# <br> **Jawab:**
# Menggunakan figsize di Matplotlib hanya akan memengaruhi ukuran tampilan gambar, bukan ukuran pixel gambar.

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Kuliah/Semester5/PCVK/Modul2/Passfoto.jpg')
foto_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Red-Blue channel
red_blue = foto_rgb.copy()
red_blue[:, :, 1] = 0  # Menghilangkan channel hijau
plt.imshow(red_blue)
plt.title('Red-Blue Channel')
plt.show()

# Green-Blue channel
green_blue = foto_rgb.copy()
green_blue[:, :, 0] = 0  # Menghilangkan channel merah
plt.imshow(green_blue)
plt.title('Green-Blue Channel')
plt.show()

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
cropped_img = foto_rgb[20:115, 25:120]
plt.imshow(cropped_img)
plt.title('Cropped Image (Rows 20-115, Cols 25-120)')
plt.show()

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
red_channel = img_rgb[5:30, :, 0]  # Mengambil channel Red (indeks 0)
plt.imshow(red_channel, cmap='Reds')  # Menggunakan colormap merah
plt.title('Red Channel (Rows 5-30)')
plt.show()

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
import random

for _ in range(5):
    x1 = random.randint(0, foto_rgb.shape[1] - 1)
    y1 = random.randint(0, foto_rgb.shape[0] - 1)
    width = random.randint(20, 100)
    height = random.randint(20, 200)
    color = [random.randint(0, 255) for _ in range(3)]  # Warna acak BGR
    cv.rectangle(foto_rgb, pt1=(x1, y1), pt2=(x1 + width, y1 + height), color=color, thickness=-1)

plt.imshow(foto_rgb)
plt.title('Random Rectangles')
plt.show()

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
flipped_img = cv.flip(foto_rgb, 0)
plt.imshow(flipped_img)
plt.title('Flipped Image')
plt.show()

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
# Membaca gambar (contoh citra)
img = cv.imread('/content/drive/MyDrive/Kuliah/Semester5/PCVK/Modul2/Lenna.png')
b_channel = img[:, :, 0]  # Channel B

# Menggambar rectangle di sudut bawah kiri
cv.rectangle(img, (0, img.shape[0] - 100), (100, img.shape[0]), color=(0, 255, 0), thickness=3)

# Menampilkan gambar
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Rectangle di Sudut Bawah Kiri')
plt.show()

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
filename = 'Lenna.png'  # Ganti dengan nama file yang sesuai

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img, filename, (10, height - 10), font, 1, (255, 255, 255), 2, cv.LINE_AA)

# Menampilkan gambar dengan tulisan
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # TUGAS

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Kuliah/Semester5/PCVK/Modul2/KTM_Irsyad.jpg')

# Mengubah gambar dari BGR ke RGB
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Menampilkan gambar yang sudah diubah ke RGB
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# Membuat circle untuk menutupi nama

# %%
for x in range(300, 651, 50):  # range(start, stop, step) untuk menggambar setiap 50 piksel
    cv.circle(img_rgb, center=(x, 650), radius=30, color=(212, 125, 0), thickness=-1)

plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# Membuat rectangle untuk menutupi NIM

# %%
cv.rectangle(img_rgb, pt1=(280, 675), pt2=(460, 725), color=(0, 0, 200), thickness=-1)
plt.imshow(img_rgb)
plt.show()
