# %% [markdown]
# <a href="https://colab.research.google.com/github/irsyaddani/PCVK_Ganjil_2024/blob/main/Week1_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   Nama: Irsyad Danisaputra
# *   NIM: 2241720233
# *   Absen: 17
# *   Kelas: TI-3E

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://unair.ac.id/wp-content/uploads/2020/12/Kucing.jpg"]

# Baca dan tampilkan img
# Loop pada tiap url img, beberapa img dapat disimpan pada list

for url in urls:
  image = io.imread(url)                            #read img
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize img tp half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate img
  cv2_imshow(final_frame)                           #show img
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi img: tinggi x lebar = ",tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi img: tinggi x lebar =  250  x  375
# <PIL.Image.Image image mode=RGB size=375x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah img
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %% [markdown]
# # **PERTANYAAN**

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# <br>**Jawab**: karena Google Colab mudah untuk diakses, gratis, serta tidak memakan resource pada laptop kita.
# ---
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# <br> **Jawab**:
# - **Numpy (np)**: digunakan untuk operasi matematika dan array, digunakan untuk manipulasi data numerik.
# - **Pandas**: digunakan untuk manipulasi dan analisis data.
# - **CV2**: digunakan untuk pemrosesan gambar dan video.
# - **Skimage**: digunakan untuk image processing pada Python.
# - **Matplotlib**: digunakan untuk membuat visualisasi data dalam bentuk grafik dan gambar.
# ---
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
# `image = cv.resize(image, (0,0), fx=0.5, fy=0.5)`
# <br> Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# <br> **Jawab:** Kode tersebut mengecilkan gambar menjadi setengah ukuran aslinya. Jika gambar tidak diresize, gambar tetap pada ukuran aslinya.
# ---
# 4. Perhatikan potongan kode progam berikut:
#
# ```membuat garis horizontal di tengah img
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255, 255, 255]
# ```
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# <br> **Jawab**: kode [255, 255, 255] adalah kode untuk mereprentasikan warna putih dalam RGB. Dalam praktikum kali ini, kode tersebut digunakan untuk menggambar garis horizontal putih di tengah gambar.
#
# ---
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# <br>**Jawab**:
# Semakin tinggi resolusi yang dimiliki oleh gambar, maka gambar tersebut akan memiliki lebih banyak piksel, sehingga lebih detail dan tajam. Sementara, semakin rendah resolusi sebuah gambar, maka gambar tersebut akan memiliki lebih sedikit piksel, sehingga terlihat lebih kasar atau buram.

# %% [markdown]
# # **TUGAS**

# %%
# Membuat garis vertikal di tengah image
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_4[x, int((lebar)/2)] = [255,255,255]

final_frame2 = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame2)

# Membuat garis diagonal
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_5[x, int(lebar/tinggi*x)] = [255, 255, 255]
    image_5[x, int((lebar/tinggi)*(tinggi-x-1))] = [255, 255, 255]

final_frame3 = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame3)

# Membuat garis dengan panjang tertentu
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(int(tinggi/2)):
  for y in range(x):
      image_6[int(tinggi/2), int(lebar / 2) - y] = [255, 255, 255]

final_frame4 = cv.hconcat((image_2, image_6))
cv2_imshow(final_frame4)

# Membuat kumpulan pixel
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (int(tinggi/2)):
  for y in range (x):
    image_7[int((lebar)/4)-x:int((lebar)/4), int((lebar)/4)-y] = [255,255,255]

final_frame5 = cv.hconcat((image_2, image_7))
cv2_imshow(final_frame5)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>
# <PIL.Image.Image image mode=RGB size=750x250>
# <PIL.Image.Image image mode=RGB size=750x250>
# <PIL.Image.Image image mode=RGB size=750x250>

# %% [markdown]
# # **TUGAS KELOMPOK**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c4e05f5-4b9b-4b17-99da-a60fa0cdb98c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c4e05f5-4b9b-4b17-99da-a60fa0cdb98c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
files = []
for file_name in uploaded.keys():
    file_path = '/content/' + file_name
    files.append(file_path)

# %%
for file in files:
    image = io.imread(file)

    # Mengubah ukuran gambar
    image = cv.resize(image, (0, 0), fx=0.3, fy=0.3)

    # Mendapatkan tinggi dan lebar gambar
    tinggi = image.shape[0]
    lebar = image.shape[1]

    # Menutup bagian gambar dengan warna
    image[int(tinggi/1.35):int(tinggi/1.18), int(lebar/5):int(lebar/2)] = [120, 0, 200]
    image[int(tinggi/1.2):int(tinggi/1.08), int(lebar/5):int(lebar/2)] = [0, 0, 0]

    plt.imshow(image)
    plt.show()
